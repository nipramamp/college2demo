# %% [markdown]
# <a href="https://colab.research.google.com/github/nipramamp/college2demo/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Open and read the file
with open('C:\\Users\\Lenovo\\Downloads\\TeleQnA_training.txt', 'r', encoding='utf-8') as file:
    data = file.read()

# Print the first 500 characters just to inspect
print(data[:500])
# Print the first 500 characters just to inspect
print(data[:500])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-58a7418af3a7> in <cell line: 0>()
#       1 # Open and read the file
# ----> 2 with open('C:\\Users\\Lenovo\\Downloads\\TeleQnA_training.txt', 'r', encoding='utf-8') as file:
#       3     data = file.read()
#       4
#       5 # Print the first 500 characters just to inspect
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Lenovo\\Downloads\\TeleQnA_training.txt'

# %%
# Open and read the file
# Open and read the file
# Correct the file path to use forward slashes and the appropriate Linux path
# You need to replace '/path/to/your/file/TeleQnA_training.txt' with the actual path on your Linux system
with open('C:\\Users\\Lenovo\\Downloads\\TeleQnA_training.txt','r', encoding='utf-8') as file:
    data = file.read()

# Print the first 500 characters just to inspect
print(data[:500])
# Print the first 500 characters just to inspect
print(data[:500])
# Print the first 500 characters just to inspect
print(data[:500])
# Print the first 500 characters just to inspect
print(data[:500])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-1bfef9f581b6> in <cell line: 0>()
#       3 # Correct the file path to use forward slashes and the appropriate Linux path
#       4 # You need to replace '/path/to/your/file/TeleQnA_training.txt' with the actual path on your Linux system
# ----> 5 with open('C:\\Users\\Lenovo\\Downloads\\TeleQnA_training.txt','r', encoding='utf-8') as file:
#       6     data = file.read()
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Lenovo\\Downloads\\TeleQnA_training.txt'

# %%
# Open and read the file
with open('/TeleQnA_training.txt', 'r', encoding='utf-8') as file:
    data = file.read()

# Print the first 500 characters just to inspect
print(data[:500])
# Out:
# {
#     "question 0": {
#         "question": "What is the purpose of the Nmfaf_3daDataManagement_Deconfigure service operation? [3GPP Release 18]",
#         "option 1": "To configure the MFAF to map data or analytics received by the MFAF to out-bound notification endpoints",
#         "option 2": "To configure the MFAF to stop mapping data or analytics received by the MFAF to out-bound notification endpoints",
#         "option 3": "To supply data or analytics from the MFAF to notification endpoints",

# %%
import json
import pprint

# Convert text to Python object (usually a list or dictionary)
parsed_data = json.loads(data)

# Check how many items are there
print(f"Total questions: {len(parsed_data)}")

# Preview the first item nicely
pprint.pprint(parsed_data['question 0'])
# Out:
# Total questions: 1461
# {'answer': 'option 2: To configure the MFAF to stop mapping data or analytics '
#            'received by the MFAF to out-bound notification endpoints',
#  'category': 'Standards specifications',
#  'explanation': 'The Nmfaf_3daDataManagement_Deconfigure service operation is '
#                 'used to stop mapping data or analytics received by the MFAF '
#                 'to one or more out-bound notification endpoints.',
#  'option 1': 'To configure the MFAF to map data or analytics received by the '
#              'MFAF to out-bound notification endpoints',
#  'option 2': 'To configure the MFAF to stop mapping data or analytics received '
#              'by the MFAF to out-bound notification endpoints',
#  'option 3': 'To supply data or analytics from the MFAF to notification '
#              'endpoints',
#  'option 4': 'To fetch data or analytics from the MFAF based on fetch '
#              'instructions',
# ...

# %%
item = parsed_data["question 0"]

question = item["question"]
options = item["options"]

# Format options to look clean
options_text = "\n".join([f"{i+1}. {opt}" for i, opt in enumerate(options)])

# Create the prompt
prompt = f"""
Question: {question}
Options:
{options_text}

Choose the correct option (1, 2, or 3) only. Do not explain.
"""

print(prompt)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-4f044fff2c06> in <cell line: 0>()
#       2
#       3 question = item["question"]
# ----> 4 options = item["options"]
#       5
#       6 # Format options to look clean
#
# KeyError: 'options'

# %%
pprint.pprint(parsed_data["question 0"])
# Out:
# {'answer': 'option 2: To configure the MFAF to stop mapping data or analytics '
#            'received by the MFAF to out-bound notification endpoints',
#  'category': 'Standards specifications',
#  'explanation': 'The Nmfaf_3daDataManagement_Deconfigure service operation is '
#                 'used to stop mapping data or analytics received by the MFAF '
#                 'to one or more out-bound notification endpoints.',
#  'option 1': 'To configure the MFAF to map data or analytics received by the '
#              'MFAF to out-bound notification endpoints',
#  'option 2': 'To configure the MFAF to stop mapping data or analytics received '
#              'by the MFAF to out-bound notification endpoints',
#  'option 3': 'To supply data or analytics from the MFAF to notification '
#              'endpoints',
#  'option 4': 'To fetch data or analytics from the MFAF based on fetch '
#              'instructions',
# ...

# %%
item = parsed_data["question 0"]

question = item["question"]

# Extract all options (1 to 4)
options = [
    item["option 1"],
    item["option 2"],
    item["option 3"],
    item["option 4"]
]

# Format options text
options_text = "\n".join([f"{i+1}. {opt}" for i, opt in enumerate(options)])

# Create the prompt
prompt = f"""
Question: {question}
Options:
{options_text}

Choose the correct option (1, 2, 3, or 4) only. Do not explain.
"""

print(prompt)
# Out:
# Question: What is the purpose of the Nmfaf_3daDataManagement_Deconfigure service operation? [3GPP Release 18]
# Options:
# 1. To configure the MFAF to map data or analytics received by the MFAF to out-bound notification endpoints
# 2. To configure the MFAF to stop mapping data or analytics received by the MFAF to out-bound notification endpoints
# 3. To supply data or analytics from the MFAF to notification endpoints
# 4. To fetch data or analytics from the MFAF based on fetch instructions
#
# Choose the correct option (1, 2, 3, or 4) only. Do not explain.

# %%
# !pip install transformers accelerate sentencepiece
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from huggingface_hub import login

login()

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_id = "google/gemma-1.1-2b-it"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")

# Set up text generation pipeline
chatbot = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "google/gemma-1.1-2b-it"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/618 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %%
import torch

prompt = "Question: What is the purpose of the Nmfaf_3daDataManagement_Deconfigure service operation?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate output (set max length as you want)
outputs = model.generate(**inputs, max_length=100)

# Decode and print the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_text)
# Out:
# Question: What is the purpose of the Nmfaf_3daDataManagement_Deconfigure service operation?
#
# **Nmfaf_3daDataManagement_Deconfigure** is a service operation used to remove data management configurations from a Data Management Framework (DMF) instance.
#
# **Purpose:**
#
# The purpose of the Nmfaf_3daDataManagement_Deconfigure service operation is to:
#
# - Remove all data management configurations from the DMF instance.
# - Reset the DM

# %%
prompt = """
Question: What is the purpose of the Nmfaf_3daDataManagement_Deconfigure service operation?

Options:
1. To configure the MFAF to map data or analytics received by the MFAF to out-bound notification endpoints
2. To configure the MFAF to stop mapping data or analytics received by the MFAF to out-bound notification endpoints
3. To supply data or analytics from the MFAF to notification endpoints
4. To fetch data or analytics from the MFAF based on fetch instructions

Choose the correct option (1, 2, 3, or 4) only. Do not explain.
"""

inputs = tokenizer(prompt, return_tensors="pt")
outputs = model.generate(**inputs, max_length=200)
answer = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("Model Answer:", answer.strip())
# Out:
# Model Answer: Question: What is the purpose of the Nmfaf_3daDataManagement_Deconfigure service operation?
#
# Options:
# 1. To configure the MFAF to map data or analytics received by the MFAF to out-bound notification endpoints
# 2. To configure the MFAF to stop mapping data or analytics received by the MFAF to out-bound notification endpoints
# 3. To supply data or analytics from the MFAF to notification endpoints
# 4. To fetch data or analytics from the MFAF based on fetch instructions
#
# Choose the correct option (1, 2, 3, or 4) only. Do not explain.
# The purpose of the Nmfaf_3daDataManagement_Deconfigure service operation is to **configure the MFAF to stop mapping data or analytics received by the MFAF to out-bound notification endpoints**.

# %%
prompt = """
Question: What is the purpose of the Nmfaf_3daDataManagement_Deconfigure service operation?

Options:
1. To configure the MFAF to map data or analytics received by the MFAF to out-bound notification endpoints
2. To configure the MFAF to stop mapping data or analytics received by the MFAF to out-bound notification endpoints
3. To supply data or analytics from the MFAF to notification endpoints
4. To fetch data or analytics from the MFAF based on fetch instructions

Choose the correct option (1, 2, 3, or 4) only. Do not explain.
Answer:"""

inputs = tokenizer(prompt, return_tensors="pt")
outputs = model.generate(
    **inputs,
    max_length=inputs['input_ids'].shape[1] + 5,  # allow 5 tokens for the answer
    pad_token_id=tokenizer.eos_token_id,
    do_sample=False,  # deterministic output
    num_beams=5       # beam search for better quality
)
answer = tokenizer.decode(outputs[0][inputs['input_ids'].shape[1]:], skip_special_tokens=True).strip()

print("Model answer:", answer)
# Out:
# Model answer: 1
